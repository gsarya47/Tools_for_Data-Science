# %% [markdown]
# <strong>Exercise 1: Create a Jupyter Notebook</strong>

# %% [markdown]
# <p>Created this Jupyter Notebook named as DataScienceEcosystem.ipynb for Peer review<p>

# %% [markdown]
# <strong>Exercise 2: Create markdown cell with title of the notebook.</strong>

# %% [markdown]
# <h1>Data Science Tools and Ecosystem</h1>

# %% [markdown]
# <strong>Exercise 3 - Create a markdown cell for an introduction</strong>

# %% [markdown]
# <p>In this notebook, Data Science Tools and Ecosystem are summarized.<p>

# %% [markdown]
# <strong>Objectives:</strong>
# <ul>
#     <li>To list popular languages that Data Scientists use.</li>
#     <li>To list commonly used libraries used by Data Scientists.</li>
#     <li>To three development environment open source tools used in data science</li>
#     <li>Examples of evaluating arithmetic expressions in Python</li>
#     <li>Convert minutes to hours in Python</li>
# </ul>

# %% [markdown]
# <strong>Exercise 4 - Create a markdown cell to list data science languages</strong>

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# <ol>
#     <li>Python.</li>
#     <li>R.</li>
#     <li>SQL.</li>
#     <li>Julia.</li>
#     <li>Scala.</li>
#     <li>Java.</li>
#     <li>MATLAB</li>
# </ol>

# %% [markdown]
# <strong>Exercise 5 - Create a markdown cell to list data science libraries</strong>

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# <ol>
#     <li>NumPy</li>
#     <li>Pandas</li>
#     <li>Matplotlib</li>
#     <li>Seaborn</li>
#     <li>Scikit-learn</li>
#     <li>TensorFlow</li>
#     <li>PyTorch</li>
#     <li>SciPy</li>
#     <li>XGBoost</li>
#     <li>Plotly</li>
# </ol>

# %% [markdown]
# <strong>Exercise 6 - Create a markdown cell with a table of Data Science tools</strong>

# %% [markdown]
# Data Science Tools:
#
# <table style="width:100%">
#   <tr>
#     <th>Data Science Tools</th>
#     <th></th>
#     <th></th>
#   </tr>
#   <tr>
#     <td>1. Jupyter Notebook / JupyterLab</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>2. RStudio</td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>3. Visual Studio Code (VS Code)</td>
#     <td></td>
#     <td></td>
#   </tr>
# </table>

# %% [markdown]
# <strong>Exercise 7 - Create a markdown cell introducing arithmetic expression examples</strong>

# %% [markdown]
# <h3>Below are a few examples of evaluating arithmetic expressions in Python</h3>

# %%
# Basic Arithmetic operations
# Addition
2 + 3
# Out:
# 5

# %%
# Subtraction
7 - 4
# Out:
# 3

# %%
# Multiplication
6 * 5
# Out:
# 30

# %%
# Division 
15 / 3
# Out:
# 5.0

# %%
#Mixing different operations
(10 - 2) / 4 + 3
# Out:
# 5.0

# %% [markdown]
# <strong>Exercise 8 - Create a code cell to multiply and add numbers</strong>

# %%
#This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# <strong>Exercise 9 - Create a code cell to convert minutes to hours</strong>

# %%
#This will convert 200 minutes to hours by diving by 60

days = 0
hours = 0
mins = 0

time = 200
leftover_minutes = time % 1440
hours = leftover_minutes / 60
print(str(days) + " days, " + str(hours) + " hours, " + str(mins) +  " mins. ")
# Out:
# 0 days, 3.3333333333333335 hours, 0 mins.

# %% [markdown]
# <strong>Exercise 11 - Create a markdown cell to indicate the Author's name</strong>

# %% [markdown]
# <h2>Author:</h2> Gaurav Singh Arya
